# %%
import os
import sys
import glob
import datetime
import calendar
# import warnings

import numpy as np
import xarray as xr
import scipy
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt

# %%
DIR = '/glade/u/home/lgchen/ChesROMS/ChesROMS_UMD/preprocess/boundary'
FN_BRY = 'bry_ChesROMS-UMD_fromGlorys12v1_199401_daily_v01.nc'
ds = xr.open_dataset(DIR + '/' + FN_BRY)
print(ds)
# Out:
# <xarray.Dataset> Size: 14MB
# Dimensions:        (s_rho: 20, s_w: 21, bry_time: 31, eta_rho: 838,
#                     xi_rho: 518, eta_u: 838, xi_u: 517, eta_v: 837, xi_v: 518)
# Coordinates: (12/15)
#   * s_rho          (s_rho) float64 160B -0.975 -0.925 -0.875 ... -0.075 -0.025
#   * s_w            (s_w) float64 168B -1.0 -0.95 -0.9 -0.85 ... -0.1 -0.05 0.0
#     lon_rho_east   (eta_rho) float32 3kB ...
#     lat_rho_east   (eta_rho) float32 3kB ...
#     lon_rho_south  (xi_rho) float32 2kB ...
#     lat_rho_south  (xi_rho) float32 2kB ...
#     ...             ...
#     lat_u_south    (xi_u) float32 2kB ...
#     lon_v_east     (eta_v) float32 3kB ...
#     lat_v_east     (eta_v) float32 3kB ...
#     lon_v_south    (xi_v) float32 2kB ...
#     lat_v_south    (xi_v) float32 2kB ...
#   * bry_time       (bry_time) datetime64[ns] 248B 1994-01-01T12:00:00 ... 199...
# Dimensions without coordinates: eta_rho, xi_rho, eta_u, xi_u, eta_v, xi_v
# Data variables: (12/23)
# ...

# %%
print(ds['temp_south'].data[0:5, 0, 287])
# Out:
# [14.6552515 17.80788   16.890999  16.763418  14.810906 ]

# %%
print(ds['temp_south'].data[0, 0, 280:299])
# Out:
# [15.373913  15.446103  15.456722  15.349387  15.015743  14.768222
#  14.721918  14.6552515 14.5370245 14.529081  14.582911  14.820879
#  14.962523  15.15641   15.604709  16.019217  16.158056  16.221954
#  16.251078 ]

# %%
print(ds['temp_south'].data[1, 0, 280:299])
# Out:
# [17.556217 17.252926 17.489256 17.91758  17.894485 17.85547  17.831427
#  17.80788  17.784483 17.776764 17.866638 17.955551 18.043522 18.087782
#  18.128502 18.228773 18.524515 18.589334 18.682882]

# %%
print(ds['temp_south'].data[0:5, 0, 288])
# Out:
# [14.5370245 17.784483  16.767614  16.667723  14.73156  ]

# %%
print(ds['temp_south'].data[0:5, 19, 288])
# Out:
# [13.83096  17.783873 16.763624 16.65485  14.722367]

# %%
print(ds['temp_south'].data[0:5, 19, 287])
# Out:
# [13.843413 17.806946 16.8846   16.738783 14.781723]

# %%
DIR_UMD = '/glade/u/home/lgchen/ChesROMS/input_files_4UMD'
FN_GRID = 'grid_UMD.nc'
ds_grid = xr.open_dataset(DIR_UMD + '/' + FN_GRID)
print(ds_grid)
# Out:
# <xarray.Dataset> Size: 94MB
# Dimensions:    (eta_rho: 838, xi_rho: 518, bath: 0, eta_psi: 837, xi_psi: 517,
#                 eta_u: 838, xi_u: 517, eta_v: 837, xi_v: 518)
# Dimensions without coordinates: eta_rho, xi_rho, bath, eta_psi, xi_psi, eta_u,
#                                 xi_u, eta_v, xi_v
# Data variables: (12/31)
#     spherical  int32 4B ...
#     xl         float64 8B ...
#     el         float64 8B ...
#     angle      (eta_rho, xi_rho) float64 3MB ...
#     pm         (eta_rho, xi_rho) float64 3MB ...
#     pn         (eta_rho, xi_rho) float64 3MB ...
#     ...         ...
#     lon_v      (eta_v, xi_v) float64 3MB ...
#     lat_v      (eta_v, xi_v) float64 3MB ...
#     mask_rho   (eta_rho, xi_rho) float64 3MB ...
#     mask_psi   (eta_psi, xi_psi) float64 3MB ...
#     mask_u     (eta_u, xi_u) float64 3MB ...
#     mask_v     (eta_v, xi_v) float64 3MB ...
# Attributes:
#     type:     GRID file
# ...

# %%
print(ds_grid['h'].data[0, 280:299])
# Out:
# [13.         10.93249968  9.35066231  7.88833537  7.18320837  4.92564349
#   4.50798557  3.48951854  2.48286984  2.47630725  2.14288378  3.21432567
#   4.82148851  7.23223276  8.83612251  9.89447041 13.0692083  12.93003998
#  12.98274726]
